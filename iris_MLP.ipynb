# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/iris.csv")

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
x= df.drop("Name", axis = 1)
x
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 0            5.1         3.5          1.4         0.2
# 1            4.9         3.0          1.4         0.2
# 2            4.7         3.2          1.3         0.2
# 3            4.6         3.1          1.5         0.2
# 4            5.0         3.6          1.4         0.2
# ..           ...         ...          ...         ...
# 145          6.7         3.0          5.2         2.3
# 146          6.3         2.5          5.0         1.9
# 147          6.5         3.0          5.2         2.0
# 148          6.2         3.4          5.4         2.3
# 149          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
y= pd.get_dummies(df.Name)
y
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0           True            False           False
# 1           True            False           False
# 2           True            False           False
# 3           True            False           False
# 4           True            False           False
# ..           ...              ...             ...
# 145        False            False            True
# 146        False            False            True
# 147        False            False            True
# 148        False            False            True
# 149        False            False            True
#
# [150 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3) #30% of the data is used for testing

# %%
x_train.head()
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth
# 15          5.7         4.4          1.5         0.4
# 18          5.7         3.8          1.7         0.3
# 74          6.4         2.9          4.3         1.3
# 52          6.9         3.1          4.9         1.5
# 17          5.1         3.5          1.4         0.3

# %%
y_train
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 15          True            False           False
# 18          True            False           False
# 74         False             True           False
# 52         False             True           False
# 17          True            False           False
# ..           ...              ...             ...
# 113        False            False            True
# 106        False            False            True
# 95         False             True           False
# 73         False             True           False
# 94         False             True           False
#
# [105 rows x 3 columns]

# %%
import tensorflow as tf
import keras
from keras import layers

# %%
model = keras.Sequential()
model.add(layers.Dense(6, activation="sigmoid"))
model.add(layers.Dense(3, activation = 'softmax'))

# %%
model.compile(optimizer='rmsprop', loss= 'categorical_crossentropy', metrics=["accuracy"])

# %%
model.fit(x_train, y_train, epochs= 50, batch_size= 5)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6630 - loss: 0.8090
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6953 - loss: 0.7997
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6299 - loss: 0.8169
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7063 - loss: 0.7765
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6556 - loss: 0.7900
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6397 - loss: 0.7826
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6836 - loss: 0.7538
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7148 - loss: 0.7623
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6771 - loss: 0.7471
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7152 - loss: 0.7214
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7064 - loss: 0.7241
# Epoch 12/50
# ...

# %%
score = model.evaluate(x_test, y_test)
score
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8694 - loss: 0.4941
# [0.49409714341163635, 0.8666666746139526]

# %%
#An accuracy of 0.8694 (86.94%) is achieved on the test set using untuned model.
#The model is trained for 50 epochs with a batch size of 5.

# %%
#Code for hyperparameter tuning using Keras Tuner

# %%
def model_builder(hp):
  model = tf.keras.Sequential()
  model.add(tf.keras.Input(shape=(4,)))

  hp_activation = hp.Choice('activation', values=['relu', 'sigmoid', 'tanh', 'softmax' ])
  hp_layer_1 = hp.Int('layer_1', min_value=1, max_value=10, step=1)
  hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

  model.add(tf.keras.layers.Dense(units=hp_layer_1, activation=hp_activation))
  model.add(tf.keras.layers.Dense(3, activation='softmax'))

  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss=tf.keras.losses.CategoricalCrossentropy(),
                metrics=['accuracy'])
  
  return model

# %%
import keras_tuner as kt

tuner = kt.Hyperband(model_builder,
                     objective='val_accuracy',
                     max_epochs=10,
                     factor=3,
                     directory='dir',
                     project_name='x')
# Out:
# Reloading Tuner from dir\x\tuner0.json

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x_train, y_train, epochs=50, validation_split=0.2, callbacks=[stop_early])

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# %%
print(f"""
The hyperparameter search is complete. The optimal number of units in the first hidden layer is {best_hps.get('layer_1')} and the optimal learning rate for the optimizer is {best_hps.get('learning_rate')}.
The optimal activation function is {best_hps.get('activation')}.""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first hidden layer is 10 and the optimal learning rate for the optimizer is 0.01.
# The optimal activation function is softmax.

# %%
model_tuned = tuner.hypermodel.build(best_hps)
history = model_tuned.fit(x_train, y_train, epochs=50, batch_size=5)
# Out:
# Epoch 1/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4276 - loss: 1.0758
# Epoch 2/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6854 - loss: 0.9272
# Epoch 3/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6422 - loss: 0.7847
# Epoch 4/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6612 - loss: 0.6991
# Epoch 5/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6862 - loss: 0.6214
# Epoch 6/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6680 - loss: 0.5995
# Epoch 7/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7146 - loss: 0.5410
# Epoch 8/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7540 - loss: 0.5124
# Epoch 9/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8082 - loss: 0.4987
# Epoch 10/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8509 - loss: 0.4832
# Epoch 11/50
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9463 - loss: 0.4840
# Epoch 12/50
# ...

# %%
score = model_tuned.evaluate(x_test, y_test)
score
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9600 - loss: 0.0957
# [0.11025311052799225, 0.9555555582046509]

# %%
#An accuracy of 0.9600 (96%) is achieved on the test set using the hyper-parameter tuned model.
